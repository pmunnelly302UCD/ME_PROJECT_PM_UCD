# %% [markdown]
# # Lorenz Lyapunov Testing

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from scipy.integrate import solve_ivp
import pysindy as ps

np.random.seed(100)

# %% [markdown]
# ### Define Lorenz System:

# %%
sigma = 10
rho = 28
beta = 8/3

def lorenz(t, x):
    return [
        sigma*(x[1] - x[0]),
        x[0]*(rho - x[2]) - x[1],
        x[0]*x[1] - beta*x[2]
    ]

# %% [markdown]
# ### Create Training Data:

# %%
dt = 0.01  # Timestep

# First trajectory:
t_train1 = np.arange(0,10,dt)  # Time range to integrate over
x0_train1 = [-1,1,-1]  # Initial conditions
sol1 = solve_ivp(lorenz, (t_train1[0], t_train1[-1]), x0_train1, t_eval=t_train1)  # Integrate to produce x(t),y(t),z(t)
x_train1 = np.transpose(sol1.y)  
print(x_train1)

# Second trajectory:
t_train2 = np.arange(100,110,dt)  # Time range to integrate over
x0_train2 = [2,-2,2]  # Initial conditions
sol2 = solve_ivp(lorenz, (t_train2[0], t_train2[-1]), x0_train2, t_eval=t_train2) # Integrate to produce x(t),y(t),z(t)
x_train2 = np.transpose(sol2.y)  

# Add noise to both our trajectories:
x_train1 += np.random.normal(scale = 0.05, size=x_train1.shape) 
x_train2 += np.random.normal(scale = 0.05, size=x_train2.shape) 

# Combine both trajectory data sets into a list:
x_train = [x_train1, x_train2]
# Out:
# [[-1.          1.         -1.        ]
#  [-0.82317968  0.72810065 -0.9814329 ]
#  [-0.6867448   0.50415259 -0.96014873]
#  ...
#  [ 7.47777835  5.82310483 27.94802741]
#  [ 7.31768074  5.78198091 27.62973933]
#  [ 7.17022553  5.76316816 27.31243327]]

# %% [markdown]
# ### Create SINDy Model:

# %%
stlsq_opt = ps.STLSQ(threshold = 0.1) # Set threshold
model = ps.SINDy(optimizer=stlsq_opt)
model.fit(x_train, t=dt, multiple_trajectories=True)
model.print()
# Out:
# x0' = -9.942 x0 + 9.947 x1
# x1' = 27.411 x0 + -0.858 x1 + -0.983 x0 x2
# x2' = -0.143 1 + -2.651 x2 + 0.995 x0 x1

# %% [markdown]
# ### Create test trajectory:

# %%
# Evolve the Lorenz equations in time using a different initial condition
t_test = np.arange(0, 100, dt)  # Longer time range
x0_test = np.array([8, 7, 15])  # New initial conditions
sol = solve_ivp(lorenz, (t_test[0], t_test[-1]), x0_test, t_eval=t_test) # Integrate to produce x(t),y(t),z(t)
x_test = np.transpose(sol.y)  

print('Model score: %f' % model.score(x_test, t=dt))
# Out:
# Model score: 0.999914

# %% [markdown]
# ### Simulate forward in time

# %%
x_test_sim = model.simulate(x0_test, t_test)

# %%
fig, axs = plt.subplots(x_test.shape[1], 1, sharex=True, figsize=(9,11))
for i in range(x_test.shape[1]):
    axs[i].plot(t_test, x_test[:, i], 'k', label='true simulation')
    axs[i].plot(t_test, x_test_sim[:, i], 'r--', label='model simulation')
    axs[i].legend()
    axs[i].set(xlabel='t', ylabel='$x_{}$'.format(i))
    
fig = plt.figure(figsize=(10, 4.5))
ax1 = fig.add_subplot(121, projection='3d')
ax1.plot(x_test[:, 0], x_test[:, 1], x_test[:, 2], 'k')
ax1.set(xlabel='$x_0$', ylabel='$x_1$',
        zlabel='$x_2$', title='true simulation')


ax2 = fig.add_subplot(122, projection='3d')
ax2.plot(x_test_sim[:, 0], x_test_sim[:, 1], x_test_sim[:, 2], 'r--')
ax2.set(xlabel='$x_0$', ylabel='$x_1$',
        zlabel='$x_2$', title='model simulation')
# Out:
# [Text(0.5, 0, '$x_0$'),
#  Text(0.5, 0, '$x_1$'),
#  Text(0.5, 0, '$x_2$'),
#  Text(0.5, 0.92, 'model simulation')]

# %%
epsilon = 0.01  # Pertibation Amplitude
T = 0.5  # Integral time interval
M = 100  # Integral iterations
N = 3 # Number of state variables in our system

# %%
# Reference vector:
x = [8,7,15]

# Perturbed vector:
x_tilda = np.zeros((N,N))

# Perturned vector relative to reference vector
x_tilda_r = np.zeros((N,N))
x_tilda_n = np.zeros((N,N))

# Orthonormalised perturbed vector
x_tilda_0 = [[8+epsilon, 7, 15],
             [8, 7+epsilon, 15],
             [8, 7, 15+epsilon]]

x_tilda_0_r = np.zeros((N,N))

S = np.zeros(N)

# %%
for i in range(M):
    # Integrate reference vector over time T:
    sol = solve_ivp(lorenz, (i*T, (i+1)*T), x, method='BDF', t_eval=np.arange(i*T,(i+1)*T,dt))
    x = (np.transpose(sol.y))[-1]     
    
    for j in range(N):
        # Integrate each perturbation vector over time T:
        # x_tilda(j) = final value of integral from (x_tilda_0(j)) over T
        sol = solve_ivp(lorenz, (i*T, (i+1)*T), x_tilda_0[j], method='BDF', t_eval=np.arange(i*T,(i+1)*T,dt))
        x_tilda[j] = (np.transpose(sol.y))[-1]
        #print("Perturbation", x_tilda[j])
        
        # Find the relative vector between each perturbation vector and the refernce vector:
        x_tilda_r[j] = x_tilda[j] - x
        #print("Perturbation", x_tilda_r[j])

    S[0] = S[0] + np.log(np.linalg.norm(x_tilda_r[0]/epsilon))
    #print("norm0", np.sqrt(np.dot(x_tilda_r[0], x_tilda_r[0])))
    x_tilda_n[0] = x_tilda_r[0] * epsilon / np.sqrt(np.dot(x_tilda_r[0], x_tilda_r[0]))
    
    x_tilda_r[1] = x_tilda_r[1] - (np.dot(x_tilda_r[0], x_tilda_r[1])/np.dot(x_tilda_r[0], x_tilda_r[0])) * x_tilda_r[0] 
    S[1] = S[1] + np.log(np.linalg.norm(x_tilda_r[1]/epsilon))
    #print("norm1", np.sqrt(np.dot(x_tilda_r[1], x_tilda_r[1])))
    x_tilda_n[1] = x_tilda_r[1] * epsilon / np.sqrt(np.dot(x_tilda_r[1], x_tilda_r[1]))
    #print("Perturbation", x_tilda_r[0])

    x_tilda_r[2] = x_tilda_r[2] - (np.dot(x_tilda_r[0], x_tilda_r[2])/np.dot(x_tilda_r[0], x_tilda_r[0])) * x_tilda_r[0] - (np.dot(x_tilda_r[1], x_tilda_r[2])/np.dot(x_tilda_r[1], x_tilda_r[1])) * x_tilda_r[1] 
    S[2] = S[2] + np.log(np.linalg.norm(x_tilda_r[2]/epsilon))
    #print("norm2", np.sqrt(np.dot(x_tilda_r[2], x_tilda_r[2])))
    x_tilda_n[2] = x_tilda_r[2] * epsilon / np.sqrt(np.dot(x_tilda_r[2], x_tilda_r[2]))
    #print(S[0], S[1], S[2])     
    # Veryfy that the dot product is zero, i.e., the vectors are orthogonal
    #dotp1 = np.dot (x_tilda_n[0],x_tilda_n[1])
    #dotp2 = np.dot (x_tilda_n[1],x_tilda_n[2])
    #dotp3 = np.dot (x_tilda_n[2],x_tilda_n[0])
    #print("Dot product 0-1, 1-2, 2-0", dotp1, dotp2, dotp3)
        # Complete a gram schmidt orthogonalization process on relative perturbed vectors: 

    for j in range(N):
        # Compute the absolute vectors for the next iteration:
        x_tilda_0[j] = x + x_tilda_n[j]
# Out:
# [ 0.00016252  0.00254301 -0.00498038]
# [-0.00234659 -0.00262127 -0.00141501]
# [-4.38884698e-05  3.14059334e-05  1.46039408e-05]
#
#
# [-0.00677874 -0.0569176   0.03583318]
# [0.00385085 0.00332968 0.00601736]
# [ 1.64327313e-04 -6.36157940e-05 -6.99610240e-05]
#
#
# [ 0.00138756  0.00225652 -0.00222781]
# [-0.00644423 -0.01171699 -0.01588162]
# [ 3.02057743e-05 -1.77474444e-05  8.37054066e-07]
#
#
# [-0.01020787  0.00753026  0.02146744]
# [ 0.00555531  0.00899432 -0.00051342]
# [-1.25148521e-04  7.24499016e-05 -8.49223613e-05]
#
#
# [ 0.00297367 -0.004996    0.01715711]
# [0.00524986 0.00900906 0.00171346]
# [-0.00046174  0.00024053  0.00015007]
#
#
# [ 0.00494637  0.00802379 -0.0008881 ]
# [-0.00060726 -0.00034682 -0.00651564]
# [-9.19555093e-06  5.72981884e-06  5.52036607e-07]
#
#
# [-0.06446068 -0.12497179 -0.04112742]
# [ 0.00159988 -0.00240481  0.0047998 ]
# [ 6.94108327e-05 -2.41983476e-05 -3.52601301e-05]
#
#
# [-0.00155012 -0.00338704  0.00165913]
# [-0.00307515  0.01176737  0.02114947]
# [-0.00037447  0.00011372 -0.00011772]
#
#
# [ 0.00222768  0.00149842 -0.00588179]
# [-0.00474375 -0.00845388 -0.00395033]
# [-1.57889619e-05  1.04142782e-05 -3.32684806e-06]
#
#
# [-0.00321977  0.00274225  0.00777532]
# [ 0.01616619  0.02972771 -0.00379014]
# [-0.00148126  0.00069602 -0.00085887]
#
#
# [ 0.04500356  0.08283968 -0.00329257]
# [-2.55102709e-05 -6.68906108e-05 -2.03162065e-03]
# [ 1.16937802e-04 -6.35029875e-05  6.22477726e-07]
#
#
# [-0.09493303 -0.11437751  0.09393959]
# [-0.00076687  0.00345527  0.00343203]
# [-7.89203217e-05  2.79277117e-05 -4.57511414e-05]
#
#
# [ 0.00022723  0.00655204 -0.0049262 ]
# [0.00090612 0.00385463 0.00516861]
# [ 0.0025659  -0.00027372 -0.0002457 ]
#
#
# [-0.0084607  -0.01027494 -0.01079431]
# [ 0.0007896   0.00267243 -0.00316275]
# [ 1.45927148e-05 -8.39305446e-06 -3.44871528e-06]
#
#
# [-0.00240561 -0.0066251   0.00443113]
# [-0.00649596 -0.00405972 -0.00959637]
# [ 1.13184584e-05 -7.19764141e-06 -4.61672439e-06]
#
#
# [0.01704115 0.02051692 0.0171338 ]
# [ 0.00058243 -0.00530085  0.00576823]
# [-7.09675063e-05  2.99646638e-05  3.47024785e-05]
#
#
# [-0.00976781 -0.01109031 -0.01761618]
# [ 0.0014874   0.00445826 -0.00363144]
# [ 3.61597203e-07 -1.87700869e-07 -8.23306068e-08]
#
#
# [-0.00195455 -0.00385849  0.00283522]
# [-0.00568327 -0.00516534 -0.01094751]
# [ 1.58107301e-05 -1.04256862e-05 -3.28882637e-06]
#
#
# [0.02778677 0.02221756 0.03214492]
# [-0.00014019 -0.00546863  0.00390093]
# [ 1.32366243e-05 -5.69396119e-06 -7.50653722e-06]
#
#
# [-0.00199628 -0.00371118  0.00143748]
# [-0.0045337  -0.00784399 -0.02654724]
# [ 1.84011808e-05 -9.97390362e-06 -1.95510277e-07]
#
#
# [-0.00336764  0.40017038 -0.37073145]
# [0.00274613 0.00389342 0.00417764]
# [ 2.56851426e-04 -8.27818819e-05 -9.16885807e-05]
#
#
# [ 0.00097423  0.00078228 -0.00146264]
# [0.00286255 0.00685908 0.00557519]
# [ 0.00035268 -0.00023567  0.00010886]
#
#
# [0.00222349 0.00504213 0.00266407]
# [-0.00578737 -0.00384141  0.01210066]
# [ 1.25264370e-05 -7.44123873e-06  3.62874731e-06]
#
#
# [-0.00582471  0.00147027  0.01416353]
# [-0.00308872 -0.00594617 -0.00065298]
# [ 1.10351155e-05 -6.30235839e-06  5.19238554e-06]
#
#
# [-0.00500943 -0.01410626 -0.00243849]
# [ 0.0052207   0.00012357 -0.01143979]
# [ 2.96448176e-05 -1.28421949e-05  1.33901013e-05]
#
#
# [ 0.00554322  0.00637107 -0.00851008]
# [0.00187393 0.00682996 0.00633387]
# [ 5.96474730e-06 -3.09254218e-06  1.57003278e-06]
#
#
# [0.00152583 0.00384763 0.00350349]
# [-0.00703205 -0.00688928  0.01062859]
# [ 1.20485020e-05 -7.56911769e-06  3.06530390e-06]
#
#
# [-0.01067796 -0.00164132  0.01790877]
# [-0.00259881 -0.00687292 -0.00217941]
# [ 3.18232630e-05 -1.75401410e-05  1.73668324e-05]
#
#
# [ 0.00610521 -0.00312303 -0.0230992 ]
# [ 0.00487438  0.01072294 -0.00016143]
# [-9.88049818e-05  4.44307431e-05 -3.21216198e-05]
#
#
# [0.00195483 0.00350917 0.00154966]
# [-0.00418774 -0.00419674  0.01478606]
# [-1.69264074e-05  1.02601199e-05 -1.88180084e-06]
#
#
# [-0.01867846 -0.00081798  0.02845027]
# [-0.00231868 -0.00596386 -0.00169375]
# [-4.53079859e-06  2.58520509e-06 -2.90027817e-06]
#
#
# [0.00553029 0.0071482  0.01260009]
# [-0.01576996 -0.04294942  0.03128733]
# [ 2.68321866e-05 -1.30415295e-05 -4.37824511e-06]
#
#
# [ 0.00185164  0.00298153 -0.00462319]
# [0.00453652 0.00455758 0.00475614]
# [-4.48151018e-05  3.78593663e-05  6.46690317e-06]
#
#
# [-0.01269711 -0.0089176   0.0168267 ]
# [-0.00111007 -0.01300224 -0.0077284 ]
# [-2.63516025e-05  1.06986984e-05 -1.42144541e-05]
#
#
# [ 0.01635464  0.02940971 -0.00120314]
# [ 4.54086850e-04 -8.48627800e-05  4.09813122e-03]
# [ 2.82126553e-04 -1.58302536e-04 -3.45386576e-05]
#
#
# [-0.06527051 -0.03916951  0.07499489]
# [-0.00025269 -0.00450771 -0.00257428]
# [ 2.03372054e-05 -8.66403799e-06  1.31749484e-05]
#
#
# [-0.00198432  0.00388406 -0.00973875]
# [0.00593101 0.01053796 0.00299433]
# [ 0.00048932 -0.00022192 -0.00018821]
#
#
# [-0.00449417 -0.00691846 -0.00242369]
# [-3.72406852e-05  3.21209216e-03 -9.09989980e-03]
# [ 1.33260172e-05 -7.68683686e-06 -2.76784349e-06]
#
#
# [ 0.00026208 -0.00494677  0.00861866]
# [-0.00624565 -0.00704695 -0.00385475]
# [ 6.63849405e-06 -4.39375002e-06 -2.72370604e-06]
#
#
# [0.01368594 0.03203206 0.00176822]
# [ 0.0031446  -0.00179554  0.00818786]
# [ 8.35692559e-05 -3.35280128e-05 -3.94477845e-05]
#
#
# [-0.00555065 -0.00931054 -0.003296  ]
# [ 0.00046114  0.00302466 -0.00932065]
# [ 1.27373754e-05 -7.01126411e-06 -1.64506354e-06]
#
#
# [ 0.00084402 -0.00272301  0.00799695]
# [-0.00635962 -0.00742364 -0.00185658]
# [ 1.29524252e-05 -9.91016956e-06 -4.74151651e-06]
#
#
# [-0.04086081 -0.07205036  0.04550881]
# [-0.00107649 -0.00417633 -0.00757858]
# [ 1.39629365e-04 -6.80329758e-05  1.76574362e-05]
#
#
# [ 0.00105335  0.00063383 -0.00326991]
# [0.00708734 0.00839234 0.00390982]
# [ 1.82673810e-05 -1.66635384e-05  2.65457768e-06]
#
#
# [-0.00826829 -0.00498294 -0.01057727]
# [ 0.0016681   0.00834709 -0.00523626]
# [ 1.59806915e-05 -8.51401991e-06 -8.48122455e-06]
#
#
# [ 0.00315827 -0.0011395   0.01022873]
# [-0.0082986  -0.01911052  0.00043336]
# [-1.41440256e-04  6.25677980e-05  5.06420014e-05]
#
#
# [-0.00031509  0.00033751 -0.00333148]
# [0.01159908 0.0195303  0.0008816 ]
# [-1.35072634e-05  7.92806505e-06  2.08068746e-06]
#
#
# [-0.00633537 -0.00457156 -0.00555032]
# [ 0.00164063  0.00797281 -0.00843953]
# [ 1.33462242e-05 -1.00819264e-05 -6.92990275e-06]
#
#
# [-0.03811275 -0.0348187  -0.08519116]
# [-0.00337705 -0.00453593  0.00336472]
# [-4.50107381e-04  3.71770078e-04  4.94215280e-05]
#
#
# [-0.00017015 -0.0003095   0.00212852]
# [0.00942093 0.01533847 0.00298335]
# [-3.00125715e-04  1.83806088e-04  2.73527836e-06]
#
#
# [-0.00423433 -0.00610029  0.00158625]
# [-0.00895696  0.01284001  0.02546965]
# [ 2.11676901e-05 -1.12787345e-05  1.31300237e-05]
#
#
# [-0.0507073  -0.09448024 -0.01628336]
# [-0.00011579 -0.00044684  0.00295327]
# [-2.24614015e-06  1.18965324e-06  9.19326690e-08]
#
#
# [ 0.01168788 -0.00447612  0.02050333]
# [ 0.00399059  0.00564304 -0.00104288]
# [-1.23170995e-05  1.04286500e-05  9.29803203e-06]
#
#
# [-0.00038092 -0.00544847 -0.00442481]
# [-0.01076477 -0.01073737  0.01414812]
# [ 2.27293352e-04 -9.67234608e-05  9.95330132e-05]
#
#
# [-0.00091851  0.00048158  0.00554683]
# [9.04475782e-03 1.68583520e-02 3.40892662e-05]
# [ 1.11163338e-05 -5.96884932e-06  2.35899268e-06]
#
#
# [-0.00644608 -0.00830731  0.00340149]
# [1.65805454e-05 2.59883939e-03 6.37845622e-03]
# [ 1.86008900e-05 -1.23867434e-05  4.99850474e-06]
#
#
# [ 0.02137404  0.01597613 -0.02681636]
# [-0.00046136 -0.00682401 -0.0044332 ]
# [ 1.28098141e-05 -5.40650824e-06  6.98910762e-06]
#
#
# [-0.01249439 -0.02190597  0.00867564]
# [0.00038995 0.00135533 0.00398378]
# [ 6.70106997e-05 -3.59715350e-05  5.67869966e-06]
#
#
# [ 0.002308   -0.00319156 -0.01025699]
# [-0.00594255 -0.00648829  0.00068171]
# [ 4.74887174e-05 -4.10302155e-05  2.34527169e-05]
#
#
# [ 2.17466229e-03 -3.52774291e-05  4.83415969e-03]
# [ 0.02051618  0.06318004 -0.00876821]
# [ 0.00062085 -0.00024061 -0.00028105]
#
#
# [-0.01833153 -0.03146831 -0.00762187]
# [-3.76104033e-05 -4.97089133e-04  2.14278166e-03]
# [ 2.22177061e-04 -1.23435791e-04 -2.47353346e-05]
#
#
# [ 0.02131412 -0.00161618  0.03200468]
# [ 0.00255911  0.00598302 -0.00140216]
# [-4.96088476e-05  2.93086232e-05  3.45179858e-05]
#
#
# [ 0.00136231  0.00254211 -0.00072578]
# [ 0.0083974  -0.02053689 -0.05617   ]
# [ 6.20172367e-05 -2.76968215e-05  1.93980822e-05]
#
#
# [-0.01212492 -0.01859632  0.00745694]
# [0.00027538 0.0009228  0.00274906]
# [ 1.13579199e-05 -6.92899870e-06  1.18815788e-06]
#
#
# [ 0.01463898 -0.01849566 -0.03964575]
# [-0.00835895 -0.01195172  0.00248926]
# [-1.62877825e-05  9.24104571e-06 -1.03253373e-05]
# [-0.02101759 -0.04176786 -0.01875765]
# [-0.00120676  0.00224438 -0.00364543]
# [-3.34954321e-04  9.30306770e-05  1.68157520e-04]
#
#
# [0.00146097 0.00100019 0.00431844]
# [-0.00784409 -0.01086177  0.00516942]
# [-5.55407271e-05  4.41825442e-05  8.55690065e-06]
#
#
# [-0.01852559 -0.02940501  0.01352339]
# [ 0.00261605 -0.00591391 -0.00927539]
# [ 6.29351338e-05 -2.43473348e-05  3.32739853e-05]
#
#
# [0.00091673 0.00154764 0.00204956]
# [-0.01563821 -0.02988879  0.02956401]
# [ 2.95117411e-06 -1.63131626e-06 -8.81807208e-08]
#
#
# [-0.00930647  0.00538512 -0.01741848]
# [ 0.00641919  0.00978181 -0.00040553]
# [ 1.69091728e-05 -1.16199168e-05 -1.26267817e-05]
#
#
# [-0.00223549 -0.00466565  0.00042547]
# [ 0.0079757  -0.0062416  -0.02653914]
# [ 0.0002509  -0.00011096  0.0001015 ]
#
#
# [ 0.01326302  0.01957275 -0.01310503]
# [0.00042553 0.00142544 0.00255959]
# [ 1.31206105e-05 -7.53990879e-06  2.01771018e-06]
#
#
# [0.00034256 0.00521031 0.00780616]
# [-0.00675935 -0.00658818  0.00469399]
# [ 1.18161165e-05 -8.46633973e-06  5.13241656e-06]
#
#
# [ 0.03152265 -0.00459717 -0.11415569]
# [0.00228214 0.00578022 0.00039741]
# [ 1.92731739e-05 -7.99745459e-06  5.64411021e-06]
#
#
# [0.00075102 0.00109136 0.00214719]
# [-0.00793694 -0.01332257  0.0095476 ]
# [ 1.24970051e-05 -7.75339456e-06 -4.30172747e-07]
#
#
# [-0.00168488  0.0062399  -0.00851109]
# [0.01249717 0.01322279 0.00722031]
# [ 2.34596971e-05 -1.40226145e-05 -1.49248109e-05]
#
#
# [ 0.04745223  0.07834235 -0.0570689 ]
# [0.00047681 0.00155927 0.00253698]
# [-1.29572312e-05  6.64644060e-06 -1.64979136e-06]
#
#
# [0.00040169 0.00163057 0.00470762]
# [-0.00745448 -0.00842982  0.00355591]
# [-7.73969834e-06  6.21476463e-06 -1.49219055e-06]
#
#
# [-0.00189439  0.00375043 -0.00634298]
# [0.02085261 0.03242388 0.01294353]
# [-0.00147616  0.00062568  0.00081082]
#
#
# [0.03787437 0.06670164 0.02631191]
# [-0.00045845 -0.00102108  0.00324838]
# [-3.56656351e-05  1.97840267e-05  1.18524953e-06]
#
#
# [-0.00235129  0.00272034 -0.01010891]
# [0.00585086 0.00639561 0.0003602 ]
# [ 5.07202108e-05 -4.50527783e-05 -2.39211641e-05]
#
#
# [-0.00132734  0.0034019   0.00586978]
# [-0.02228541 -0.03523579  0.01538186]
# [-0.00115496  0.00049199 -0.00054631]
#
#
# [ 0.01179271  0.02092231 -0.00782608]
# [0.00063899 0.00106418 0.00380784]
# [ 9.42276096e-05 -5.34389667e-05 -8.77607894e-07]
#
#
# [-0.01202989  0.00479357  0.02233621]
# [-0.00382318 -0.00640969 -0.00068351]
# [ 1.35302632e-05 -9.05468012e-06  9.23038258e-06]
#
#
# [-0.00050733 -0.00281609  0.00256234]
# [-0.02758218 -0.03170816 -0.04030944]
# [ 2.68865395e-05 -1.25796096e-05 -8.50205388e-06]
#
#
# [0.01113785 0.01791211 0.00179554]
# [ 3.15492431e-05 -3.18630253e-04  2.98291429e-03]
# [ 1.72495134e-05 -1.05941228e-05 -1.31408976e-06]
#
#
# [-0.05911273 -0.07529136 -0.05672496]
# [-0.00092302  0.0039484  -0.00427886]
# [-5.14505957e-06  1.88960872e-06  2.85354650e-06]
#
#
# [-0.00019107 -0.00080748 -0.00086847]
# [ 0.00606577  0.0078065  -0.00859285]
# [ 4.90590187e-05 -2.47106399e-05  1.21819283e-05]
#
#
# [ 0.0089814   0.01194414 -0.00611249]
# [0.00039451 0.00168218 0.00386674]
# [ 1.47483051e-05 -9.70041075e-06  2.71532713e-06]
#
#
# [-0.02771837 -0.02118492  0.03358327]
# [-0.00025793 -0.00632885 -0.00420524]
# [ 1.66592864e-05 -6.91623824e-06  9.38706340e-06]
#
#
# [0.00883343 0.0157649  0.00545556]
# [-0.00077453 -0.00177232  0.00637553]
# [ 1.15650025e-04 -6.35498581e-05 -3.61637942e-06]
#
#
# [-0.00775374  0.00509545 -0.01726308]
# [ 0.00477296  0.00610652 -0.00034135]
# [-3.30222516e-05  2.70867950e-05  2.28270694e-05]
#
#
# [-0.00164926  0.00137385  0.00520598]
# [-0.01560128 -0.03393819  0.00401375]
# [-2.30506302e-05  9.43809659e-06 -9.79317742e-06]
#
#
# [ 0.00992218  0.01471624 -0.01177918]
# [0.00082822 0.00234053 0.00362178]
# [-9.77457266e-06  5.52275790e-06 -1.33377968e-06]
#
#
# [0.0009434  0.00511818 0.00686058]
# [-0.00714304 -0.00631601  0.00569415]
# [-9.00042288e-06  6.75291484e-06 -3.80021012e-06]
#
#
# [ 0.09624135  0.16771149 -0.11037461]
# [0.00146975 0.00591211 0.01026487]
# [ 5.76514783e-05 -2.79293405e-05  7.83137338e-06]
#
#
# [-0.00054202 -0.00021655  0.00355988]
# [-0.00822025 -0.00995208 -0.001857  ]
# [ 2.09609915e-05 -1.77079390e-05  2.11429034e-06]
#
#
# [0.00729095 0.00537695 0.00802461]
# [-0.00088374 -0.00960338  0.00723776]
# [-0.00345264  0.00178203  0.00194291]
#
#
# [-0.001999   -0.00378643 -0.00080224]
# [-0.01015531  0.01755163 -0.05753607]
# [-7.99466828e-05  3.68363013e-05  2.53479261e-05]
#
#
# [0.01204596 0.01815302 0.00847344]
# [-0.00031635 -0.00107475  0.00275221]
# [-1.51962756e-05  9.21886570e-06  1.85325764e-06]

# %%
L_exp = S/(M*T)

print(L_exp)
# Out:
# [  0.85811677   0.03797123 -10.70884977]
